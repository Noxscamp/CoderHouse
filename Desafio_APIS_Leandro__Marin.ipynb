# %% [markdown]
# <a href="https://colab.research.google.com/github/Noxscamp/CoderHouse/blob/main/Desafio_APIS_Leandro__Marin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Api's**
#
# Segun mi investigacion di con la Api publica Mapquest la cual ayuda a los desarrolladores soluciones geoespaciales.

# %%
import requests
from urllib.request import urlopen
import json
import pandas as pd

# %%
import requests
from requests.structures import CaseInsensitiveDict

api_key = "q5fjDfbXlkqzl1NpDu4BEjWc4gWe5dvm"
url = "http://www.mapquestapi.com/directions/v2/route?key={}".format(api_key)

headers = CaseInsensitiveDict()
headers["Content-Type"] = "application/json"

data = """
{
  "locations": [
        "Kolkata",
        "Delhi"
    ]
  }
}
"""


resp = requests.post(url, headers=headers, data=data)
resp.text
# Out:
# '{"route":{"hasTollRoad":false,"hasBridge":false,"boundingBox":{"lr":{"lng":88.349388,"lat":22.568642},"ul":{"lng":77.227028,"lat":28.657303}},"distance":904.0041,"hasTimedRestriction":false,"hasTunnel":false,"hasHighway":true,"computedWaypoints":[],"routeError":{"errorCode":-400,"message":""},"formattedTime":"16:35:19","sessionId":"6352c967-012f-993a-02b4-3875-0ab15a356ce7","hasAccessRestriction":false,"realTime":-1,"hasSeasonalClosure":false,"hasCountryCross":false,"fuelUsed":37.66,"legs":[{"hasTollRoad":false,"hasBridge":false,"destNarrative":"Proceed to DELHI, DELHI.","distance":904.0041,"hasTimedRestriction":false,"hasTunnel":false,"hasHighway":true,"index":0,"formattedTime":"16:35:19","origIndex":5,"hasAccessRestriction":false,"hasSeasonalClosure":false,"hasCountryCross":false,"roadGradeStrategy":[[]],"destIndex":35,"time":59719,"hasUnpaved":false,"origNarrative":"Go west on Rabindra Setu.","maneuvers":[{"distance":0.414,"streets":[],"narrative":"Start out going north toward Go
# ...

# %%
texto=resp.text
texto2= json.loads(texto)

# %%
print(len(resp.text))
resp.text
# Out:
# 32439
# ...

# %%
jsondata=json.loads(texto)
resp2=pd.DataFrame.from_dict(jsondata)
resp2.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-bb4fcd9e5e72> in <module>
# ----> 1 jsondata=json.loads(texto2)
#       2 resp2=pd.DataFrame.from_dict(jsondata)
#       3 resp2.head()
#
# /usr/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not dict

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize
json_normalize(texto2['route'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
#    hasTollRoad  hasBridge  distance  hasTimedRestriction  hasTunnel  \
# 0        False      False  904.0041                False      False
#
#    hasHighway computedWaypoints formattedTime  \
# 0        True                []      16:35:19
#
#                                    sessionId  hasAccessRestriction  ...  \
# 0  6352c967-012f-993a-02b4-3875-0ab15a356ce7                 False  ...
#
#    options.walkingSpeed  options.urbanAvoidFactor  \
# 0                    -1                        -1
#
#    options.stateBoundaryDisplay  options.unit options.highwayEfficiency  \
# 0                          True             M                        22
#
#   options.maxLinkId  options.maneuverPenalty  options.avoidTripIds  \
# ...
